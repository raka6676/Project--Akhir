# %% [markdown]
# # LAPORAN PROJECT
# _“BAHASA PEMROGRAMAN PYGAME DAN KIVY”_
#
# ![utm.png](attachment:utm.png)
#
#
#                                                             Penyusun :
#                                                 1. Rizqi Afif Khairullah (180441100034)
#                                                 2. Ahmad Marzuq Alhimni  (180441100071)
#
#                                                   PROGRAM STUDI SISTEM INFORMASI
#                                                      URUSAN TEKNIK INFORMATIKA
#                                                           FAKULTAS TEKNIK
#                                                     UNIVERSITAS TRUNOJOYO MADURA
#                                                                 2019
#
#
# __PYGAME__
#
# __A.PENGERTIAN PYGAME__
#
#    adalah modul cross-platform dari Python dirancang untuk membuat game. Modulnya dirancang untuk menjadi sederhana, mudah digunakan, dan menyenangkan, kunci dari idologi Pygame.
#
# __B.CARA INSTALASI PYGAME__
#
# Sebelum menggunakan Pygame ada langkah - langkah yg harus di lakukan agar pygame bisa berjalan, berikut langkah - langkahnya.
#
# 1.Buka CMD, kemudian ketikkan “pip”
# 2.Setelah muncul menu dari pip itu sendiri kemudian ketik “pip install pygame”
# 3.Kemudian akan otomatis mendownload file instalasi modul pygame. Jika sudah muncul tulisan “Successfully installed pygame-1.9.6” , maka pygame sudah terinstall.
# 4.Dan Pygame siap di gunakan dengan import pygame
#
#
#
# __C.Code Project__
# ![PROJECT.png](attachment:PROJECT.png)
#
# __D.PENJELASAN CLASS__
#
# Global Variable :
# - BLACK,WHITE,BLUE,GREEN,RED,PURPLE,LIGHT_BLUE
#
# Class Wall :
# ![CLASS%20WALL.PNG](attachment:CLASS%20WALL.PNG)
#
# Di dalam Class Wall terdapat def__init__ untuk mengatur kordinat,lebar,tinggi dan warna dari Wall tersebut.
#
# Memiliki properti :
# - self.image      = Merupakan bentuk permukaan dan ukurannya
# - self.image.fill = Untuk mengambil warna
# - self.rect       = Kordinat dari image
#
# Class Player :
# ![CLASS%20PAYER.PNG](attachment:CLASS%20PAYER.PNG)
#
#    Di dalam Class Player terdapat def__init untuk mengatur kordinat player, def changespeed untuk mengatur kecepatan player dengan menekan tombol, def move untuk mengatur pergerakan ke kiri ke kanan ke bawah ke atas dan didalan def  move juga untuk mengatur player tidak bisa melewati tembok.
#
# Memiliki Properti :
# - self.image      = Merupakan bentuk permukaan dan ukurannya
# - self.rect       = Kordinat dari image
# - self.change     = Untuk mengatur tombol ke atas, ke bawah, ke kiri dan ke kanan
# - block_hit_list  = Untuk mengatur agar Player tidak tembus dengan Wall
#
# Class Room :
# ![CLASS%20ROOM%20BASE.PNG](attachment:CLASS%20ROOM%20BASE.PNG)
#
#    Di dalam Class Room terdapat def__init__ untuk membuat list dari bangunan ruangan pada room dalam game,Class ini adalah dasar dari semua Room yg ada di dalam game.
#
# Memiliki properti :
# - wall_list = None untuk bahwa wall list itu tidak ada
# - enemy_sprites = None untuk bawahwa musuh tidak ada
# - self.wall_list    = untuk membuat list dari wall
# - self.enemy_sprites = untuk memasukan sprites
#
# Class Room1 :
# ![CLASS%20ROOM1.PNG](attachment:CLASS%20ROOM1.PNG)
#
#    Didalam Class Room1 terdapat def__init__ dan super__init__() dan ada variable walls untuk mengatur kordinat,lebar,tinggi dan warna walls
#
# Memiliki properti :
# - super().__init__() = untuk memanggil induk
# - variable walls     = untuk membuat wall dengan list setiap kordinat,lebar,tinggi dan warna wall tersebut
# - looping "for"      = dengan mengeluarkan wall dari induknya
#
# Class Room2:
# ![room1.png](attachment:room1.png)
#
#    Didalam Class Room1 terdapat def__init__ dan super__init__() dan ada variable walls untuk mengatur kordinat,lebar,tinggi dan warna walls
#
# Memiliki properti :
# - super().__init__() = untuk memanggil induk
# - variable walls     = untuk membuat wall dengan list setiap kordinat,lebar,tinggi dan warna wall tersebut
# - looping "for"      = dengan mengeluarkan wall dari induknya
#
# Class Room3:
# ![room3.png](attachment:room3.png)
#
#    Didalam Class Room1 terdapat def__init__ dan super__init__() dan ada variable walls untuk mengatur kordinat,lebar,tinggi dan warna walls
#
# Memiliki properti :
# - super().__init__() = untuk memanggil induk
# - variable walls     = untuk membuat wall dengan list setiap kordinat,lebar,tinggi dan warna wall tersebut
# - looping "for"      = dengan mengeluarkan wall dari induknya
#
# Def main()
# ![def%20main.png](attachment:def%20main.png)
#
# Ini merupakan bagian maknisme game ini
#
# __E.IMPLEMENTASI OOP PADA PROJECT__
#
# Pada project game yang ber judul "Maze Runner" menggunakan inheritence
#
# __D.TAMPILAN GAME__
#
# Tampian Game Room 1
#
# ![GAME1.PNG](attachment:GAME1.PNG)
#
# Tampilan Game Room 2
#
# ![GAME2.PNG](attachment:GAME2.PNG)
#
# Tampilan Game Room 3
#
# ![GAME3.PNG](attachment:GAME3.PNG)
